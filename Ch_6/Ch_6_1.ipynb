# %%
import numpy as np
from pandas import DataFrame as DF
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
pi = np.pi
log = np.log
exp = np.exp
sin = np.sin
sinh = np.sinh
tan = np.tan
tanh = np.tanh
arctan = np.arctan
arctanh = np.arctanh

# %% [markdown]
# # Chapter 6<br>Ordinary Differential Equations

# %% [markdown]
# ## 6.1 Initial Value Problems

# %%
def Euler_method(f, a, b, h, y_0):
    n = int((b - a)/h)
    t = np.linspace(a, b, n+1)
    w = np.zeros(n+1)
    w[0] = y_0
    
    for i in range(n):
        w[i+1] = w[i] + h*(f(t[i], w[i]))
        
    return t, w

# %% [markdown]
# ### Q. 1

# %%
a, b = 0, 1
h = 0.1
y_0 = 1

# %%
# (a)
def f(t, y):
    return t

def exact_sol(t):
    return (t**2)/2 + 1

# %%
t, w = Euler_method(f, a, b, h, y_0)
true_value = exact_sol(t)
error = abs(true_value - w)

DF({"t": t, "w": w, "Error": error, 'True value': true_value}).set_index('t')[['True value', 'w', 'Error']]
# Out:
#      True value     w  Error
# t
# 0.0       1.000  1.00  0.000
# 0.1       1.005  1.00  0.005
# 0.2       1.020  1.01  0.010
# 0.3       1.045  1.03  0.015
# 0.4       1.080  1.06  0.020
# 0.5       1.125  1.10  0.025
# 0.6       1.180  1.15  0.030
# 0.7       1.245  1.21  0.035
# 0.8       1.320  1.28  0.040
# 0.9       1.405  1.36  0.045
# 1.0       1.500  1.45  0.050

# %%
# (b)
def f(t, y):
    return (t**2)*y

def exact_sol(t):
    return exp((t**3)/3)

# %%
t, w = Euler_method(f, a, b, h, y_0)
true_value = exact_sol(t)
error = abs(true_value - w)

DF({"t": t, "w": w, "Error": error, 'True value': true_value}).set_index('t')[['True value', 'w', 'Error']]
# Out:
#      True value         w     Error
# t
# 0.0    1.000000  1.000000  0.000000
# 0.1    1.000333  1.000000  0.000333
# 0.2    1.002670  1.001000  0.001670
# 0.3    1.009041  1.005004  0.004037
# 0.4    1.021563  1.014049  0.007513
# 0.5    1.042547  1.030274  0.012273
# 0.6    1.074655  1.056031  0.018625
# 0.7    1.121126  1.094048  0.027078
# 0.8    1.186095  1.147656  0.038439
# 0.9    1.275069  1.221106  0.053963
# 1.0    1.395612  1.320016  0.075597

# %%
# (c)
def f(t, y):
    return 2*(t + 1)*y

def exact_sol(t):
    return exp((t+1)**2 - 1)

# %%
t, w = Euler_method(f, a, b, h, y_0)
true_value = exact_sol(t)
error = abs(true_value - w)

DF({"t": t, "w": w, "Error": error, 'True value': true_value}).set_index('t')[['True value', 'w', 'Error']]
# Out:
#      True value          w     Error
# t
# 0.0    1.000000   1.000000  0.000000
# 0.1    1.233678   1.200000  0.033678
# 0.2    1.552707   1.464000  0.088707
# 0.3    1.993716   1.815360  0.178356
# 0.4    2.611696   2.287354  0.324343
# 0.5    3.490343   2.927813  0.562530
# 0.6    4.758821   3.806156  0.952665
# 0.7    6.619369   5.024126  1.595242
# 0.8    9.393331   6.732329  2.661002
# 0.9   13.599051   9.155968  4.443083
# 1.0   20.085537  12.635236  7.450301

# %%
# (d)
def f(t, y):
    return 5*(t**4)*y

def exact_sol(t):
    return exp(t**5)

# %%
t, w = Euler_method(f, a, b, h, y_0)
true_value = exact_sol(t)
error = abs(true_value - w)

DF({"t": t, "w": w, "Error": error, 'True value': true_value}).set_index('t')[['True value', 'w', 'Error']]
# Out:
#      True value         w     Error
# t
# 0.0    1.000000  1.000000  0.000000
# 0.1    1.000010  1.000000  0.000010
# 0.2    1.000320  1.000050  0.000270
# 0.3    1.002433  1.000850  0.001583
# 0.4    1.010293  1.004903  0.005389
# 0.5    1.031743  1.017766  0.013977
# 0.6    1.080863  1.049571  0.031292
# 0.7    1.183019  1.117584  0.065436
# 0.8    1.387745  1.251750  0.135995
# 0.9    1.804873  1.508108  0.296765
# 1.0    2.718282  2.002843  0.715439

# %%
# (e)
def f(t, y):
    return y**(-2)

def exact_sol(t):
    return (3*t + 1)**(1/3)

# %%
t, w = Euler_method(f, a, b, h, y_0)
true_value = exact_sol(t)
error = abs(true_value - w)

DF({"t": t, "w": w, "Error": error, 'True value': true_value}).set_index('t')[['True value', 'w', 'Error']]
# Out:
#      True value         w     Error
# t
# 0.0    1.000000  1.000000  0.000000
# 0.1    1.091393  1.100000  0.008607
# 0.2    1.169607  1.182645  0.013038
# 0.3    1.238562  1.254142  0.015580
# 0.4    1.300591  1.317720  0.017129
# 0.5    1.357209  1.375311  0.018102
# 0.6    1.409460  1.428180  0.018720
# 0.7    1.458100  1.477207  0.019107
# 0.8    1.503695  1.523033  0.019339
# 0.9    1.546680  1.566143  0.019463
# 1.0    1.587401  1.606913  0.019512

# %%
# (f)
def f(t, y):
    return t**3 / y**2

def exact_sol(t):
    return (0.75*(t**4) + 1)**(1/3)

# %%
t, w = Euler_method(f, a, b, h, y_0)
true_value = exact_sol(t)
error = abs(true_value - w)

DF({"t": t, "w": w, "Error": error, 'True value': true_value}).set_index('t')[['True value', 'w', 'Error']]
# Out:
#      True value         w     Error
# t
# 0.0    1.000000  1.000000  0.000000
# 0.1    1.000025  1.000000  0.000025
# 0.2    1.000400  1.000100  0.000300
# 0.3    1.002021  1.000900  0.001121
# 0.4    1.006359  1.003595  0.002764
# 0.5    1.015387  1.009949  0.005438
# 0.6    1.031403  1.022204  0.009199
# 0.7    1.056744  1.042876  0.013868
# 0.8    1.093404  1.074414  0.018990
# 0.9    1.142695  1.118767  0.023928
# 1.0    1.205071  1.177011  0.028061

# %% [markdown]
# ### Q. 2

# %%
a, b = 0, 1
h_list = [0.1, 0.05, 0.025]
t_list = np.linspace(0, 1, 41)
y_0 = 1

# %%
# (a)
def f(t, y):
    return t

def exact_sol(t):
    return (t**2)/2 + 1

# %%
plt.figure()

true_value = exact_sol(t_list)
plt.plot(t_list, true_value, label='$(t^2)/2 + 1$')

for h in h_list:
    t, w = Euler_method(f, a, b, h, y_0)
    plt.plot(t, w, label='h: %.3f' % h)
    
plt.legend()
plt.show()

# %%
# (b)
def f(t, y):
    return (t**2)*y

def exact_sol(t):
    return exp((t**3)/3)

# %%
plt.figure()

true_value = exact_sol(t_list)
plt.plot(t_list, true_value, label='$exp(t^3/3)$')

for h in h_list:
    t, w = Euler_method(f, a, b, h, y_0)
    plt.plot(t, w, label='h: %.3f' % h)
    
plt.legend()
plt.show()

# %%
# (c)
def f(t, y):
    return 2*(t + 1)*y

def exact_sol(t):
    return exp((t+1)**2 - 1)

# %%
plt.figure()

true_value = exact_sol(t_list)
plt.plot(t_list, true_value, label='$exp((t+1)^2 - 1)$')

for h in h_list:
    t, w = Euler_method(f, a, b, h, y_0)
    plt.plot(t, w, label='h: %.3f' % h)
    
plt.legend()
plt.show()

# %%
# (d)
def f(t, y):
    return 5*(t**4)*y

def exact_sol(t):
    return exp(t**5)

# %%
plt.figure()

true_value = exact_sol(t_list)
plt.plot(t_list, true_value, label='$exp(t^5)$')

for h in h_list:
    t, w = Euler_method(f, a, b, h, y_0)
    plt.plot(t, w, label='h: %.3f' % h)
    
plt.legend()
plt.show()

# %%
# (e)
def f(t, y):
    return y**(-2)

def exact_sol(t):
    return (3*t + 1)**(1/3)

# %%
plt.figure()

true_value = exact_sol(t_list)
plt.plot(t_list, true_value, label='$\sqrt[3]{(3t + 1)}$')

for h in h_list:
    t, w = Euler_method(f, a, b, h, y_0)
    plt.plot(t, w, label='h: %.3f' % h)
    
plt.legend()
plt.show()

# %%
# (f)
def f(t, y):
    return t**3 / y**2

def exact_sol(t):
    return (0.75*(t**4) + 1)**(1/3)

# %%
plt.figure()

true_value = exact_sol(t_list)
plt.plot(t_list, true_value, label='$\sqrt[3]{(3/4)t^4 + 1}$')

for h in h_list:
    t, w = Euler_method(f, a, b, h, y_0)
    plt.plot(t, w, label='h: %.3f' % h)
    
plt.legend()
plt.show()

# %% [markdown]
# ### Q. 3

# %%
a, b = 0, 1
h_list = [0.1, 0.05, 0.025]
t_list = np.linspace(0, 1, 41)
y_0 = 0

# %%
# (a)
def f(t, y):
    return t + y

def exact_sol(t):
    return exp(t) - t - 1

# %%
plt.figure()

true_value = exact_sol(t_list)
plt.plot(t_list, true_value, label='$e^t - t - 1$')

for h in h_list:
    t, w = Euler_method(f, a, b, h, y_0)
    plt.plot(t, w, label='h: %.3f' % h)
    
plt.legend()
plt.show()

# %%
# (b)
def f(t, y):
    return t - y

def exact_sol(t):
    return exp(-t) + t - 1

# %%
plt.figure()

true_value = exact_sol(t_list)
plt.plot(t_list, true_value, label='$exp(-t) + t - 1$')

for h in h_list:
    t, w = Euler_method(f, a, b, h, y_0)
    plt.plot(t, w, label='h: %.3f' % h)
    
plt.legend()
plt.show()

# %%
# (c)
def f(t, y):
    return 4*t - 2*y

def exact_sol(t):
    return exp(-2*t) + 2*t - 1

# %%
plt.figure()

true_value = exact_sol(t_list)
plt.plot(t_list, true_value, label='$exp(-2t) + 2t - 1$')

for h in h_list:
    t, w = Euler_method(f, a, b, h, y_0)
    plt.plot(t, w, label='h: %.3f' % h)
    
plt.legend()
plt.show()

# %% [markdown]
# ### Q. 4

# %%
a, b = 0, 1
h_list = [0.1*(2**(-k)) for k in range(6)]
y_0 = 1

# %%
# (a)
def f(t, y):
    return t

def exact_sol(t):
    return (t**2)/2 + 1

# %%
f_1 = exact_sol(1)
error_list = np.zeros(6)
for i, h in enumerate(h_list):
    t, w = Euler_method(f, a, b, h, y_0)
    error_list[i] = abs(w[-1] - f_1)

plt.plot(h_list, error_list)
plt.xlabel('h')
plt.ylabel("Error")
plt.xscale("log")
plt.yscale("log")
plt.show()

# %%
# (b)
def f(t, y):
    return (t**2)*y

def exact_sol(t):
    return exp((t**3)/3)

# %%
f_1 = exact_sol(1)
error_list = np.zeros(6)
for i, h in enumerate(h_list):
    t, w = Euler_method(f, a, b, h, y_0)
    error_list[i] = abs(w[-1] - f_1)

plt.plot(h_list, error_list)
plt.xlabel('h')
plt.ylabel("Error")
plt.xscale("log")
plt.yscale("log")
plt.show()

# %%
# (c)
def f(t, y):
    return 2*(t + 1)*y

def exact_sol(t):
    return exp((t+1)**2 - 1)

# %%
f_1 = exact_sol(1)
error_list = np.zeros(6)
for i, h in enumerate(h_list):
    t, w = Euler_method(f, a, b, h, y_0)
    error_list[i] = abs(w[-1] - f_1)

plt.plot(h_list, error_list)
plt.xlabel('h')
plt.ylabel("Error")
plt.xscale("log")
plt.yscale("log")
plt.show()

# %%
# (d)
def f(t, y):
    return 5*(t**4)*y

def exact_sol(t):
    return exp(t**5)

# %%
f_1 = exact_sol(1)
error_list = np.zeros(6)
for i, h in enumerate(h_list):
    t, w = Euler_method(f, a, b, h, y_0)
    error_list[i] = abs(w[-1] - f_1)

plt.plot(h_list, error_list)
plt.xlabel('h')
plt.ylabel("Error")
plt.xscale("log")
plt.yscale("log")
plt.show()

# %%
# (e)
def f(t, y):
    return y**(-2)

def exact_sol(t):
    return (3*t + 1)**(1/3)

# %%
f_1 = exact_sol(1)
error_list = np.zeros(6)
for i, h in enumerate(h_list):
    t, w = Euler_method(f, a, b, h, y_0)
    error_list[i] = abs(w[-1] - f_1)

plt.plot(h_list, error_list)
plt.xlabel('h')
plt.ylabel("Error")
plt.xscale("log")
plt.yscale("log")
plt.show()

# %%
# (f)
def f(t, y):
    return t**3 / y**2

def exact_sol(t):
    return (0.75*(t**4) + 1)**(1/3)

# %%
f_1 = exact_sol(1)
error_list = np.zeros(6)
for i, h in enumerate(h_list):
    t, w = Euler_method(f, a, b, h, y_0)
    error_list[i] = abs(w[-1] - f_1)

plt.plot(h_list, error_list)
plt.xlabel('h')
plt.ylabel("Error")
plt.xscale("log")
plt.yscale("log")
plt.show()

# %% [markdown]
# ### Q. 5

# %%
a, b = 0, 1
h_list = [0.1*(2**(-k)) for k in range(6)]
y_0 = 0

# %%
# (a)
def f(t, y):
    return t + y

def exact_sol(t):
    return exp(t) - t - 1

# %%
f_1 = exact_sol(1)
error_list = np.zeros(6)
for i, h in enumerate(h_list):
    t, w = Euler_method(f, a, b, h, y_0)
    error_list[i] = abs(w[-1] - f_1)

plt.plot(h_list, error_list)
plt.xlabel('h')
plt.ylabel("Error")
plt.xscale("log")
plt.yscale("log")
plt.show()

# %%
# (b)
def f(t, y):
    return t - y

def exact_sol(t):
    return exp(-t) + t - 1

# %%
f_1 = exact_sol(1)
error_list = np.zeros(6)
for i, h in enumerate(h_list):
    t, w = Euler_method(f, a, b, h, y_0)
    error_list[i] = abs(w[-1] - f_1)

plt.plot(h_list, error_list)
plt.xlabel('h')
plt.ylabel("Error")
plt.xscale("log")
plt.yscale("log")
plt.show()

# %%
# (c)
def f(t, y):
    return 4*t - 2*y

def exact_sol(t):
    return exp(-2*t) + 2*t - 1

# %%
f_1 = exact_sol(1)
error_list = np.zeros(6)
for i, h in enumerate(h_list):
    t, w = Euler_method(f, a, b, h, y_0)
    error_list[i] = abs(w[-1] - f_1)

plt.plot(h_list, error_list)
plt.xlabel('h')
plt.ylabel("Error")
plt.xscale("log")
plt.yscale("log")
plt.show()

# %% [markdown]
# ### Q. 6

# %%
a, b = 0, 2
h_list = [0.1*(2**(-k)) for k in range(6)]
y_0 = 0

# %%
# (a)
def f(t, y):
    return t + y

def exact_sol(t):
    return exp(t) - t - 1

# %%
f_2 = exact_sol(2)
error_list = np.zeros(6)
for i, h in enumerate(h_list):
    t, w = Euler_method(f, a, b, h, y_0)
    error_list[i] = abs(w[-1] - f_2)

plt.plot(h_list, error_list)
plt.xlabel('h')
plt.ylabel("Error")
plt.xscale("log")
plt.yscale("log")
plt.show()

# %%
# (b)
def f(t, y):
    return t - y

def exact_sol(t):
    return exp(-t) + t - 1

# %%
f_2 = exact_sol(2)
error_list = np.zeros(6)
for i, h in enumerate(h_list):
    t, w = Euler_method(f, a, b, h, y_0)
    error_list[i] = abs(w[-1] - f_2)

plt.plot(h_list, error_list)
plt.xlabel('h')
plt.ylabel("Error")
plt.xscale("log")
plt.yscale("log")
plt.show()

# %%
# (c)
def f(t, y):
    return 4*t - 2*y

def exact_sol(t):
    return exp(-2*t) + 2*t - 1

# %%
f_2 = exact_sol(2)
error_list = np.zeros(6)
for i, h in enumerate(h_list):
    t, w = Euler_method(f, a, b, h, y_0)
    error_list[i] = abs(w[-1] - f_2)

plt.plot(h_list, error_list)
plt.xlabel('h')
plt.ylabel("Error")
plt.xscale("log")
plt.yscale("log")
plt.show()

# %% [markdown]
# ### Q. 7

# %%
a, b = 0, 1
h_list = [0.1, 0.05]
t_list = np.linspace(0, 1, 21)

def f(t, y):
    return 1 + y**2

# %%
# (a)
y_0 = 0

def exact_sol(t):
    return tan(t)

# %%
plt.figure()

true_value = exact_sol(t_list)
plt.plot(t_list, true_value, label='$tan(t)$')

for h in h_list:
    t, w = Euler_method(f, a, b, h, y_0)
    plt.plot(t, w, label='h: %.2f' % h)
    
plt.legend()
plt.show()

# %%
# (b)
y_0 = 1

def exact_sol(t):
    return tan(t + pi/4)

# %%
plt.figure()

true_value = exact_sol(t_list)
plt.plot(t_list, true_value, label='$tan(t + \pi/4)$')

for h in h_list:
    t, w = Euler_method(f, a, b, h, y_0)
    plt.plot(t, w, label='h: %.2f' % h)
    
plt.legend()
plt.show()

# %% [markdown]
# ### Q. 8

# %%
a, b = 0, 1
h_list = [0.1, 0.05]
t_list = np.linspace(0, 1, 21)

def f(t, y):
    return 1 - y**2

# %%
# (a)
y_0 = 0

def exact_sol(t):
    return tanh(t)

# %%
plt.figure()

true_value = exact_sol(t_list)
plt.plot(t_list, true_value, label='$tanh(t)$')

for h in h_list:
    t, w = Euler_method(f, a, b, h, y_0)
    plt.plot(t, w, label='h: %.2f' % h)
    
plt.legend()
plt.show()

# %%
# (b)
y_0 = -1/2

def exact_sol(t):
    c = -log(3)/2
    return tanh(t + c)

# %%
plt.figure()

true_value = exact_sol(t_list)
plt.plot(t_list, true_value, label='$tanh(t - log(3)/2)$')

for h in h_list:
    t, w = Euler_method(f, a, b, h, y_0)
    plt.plot(t, w, label='h: %.2f' % h)
    
plt.legend()
plt.show()

# %% [markdown]
# ### Q. 9

# %%
a, b = 0, 4
h_list = [0.1 * 2**(-k) for k in range(6)]
t_list = np.arange(a, b+h_list[-1], h_list[-1])

def f(t, y):
    return sin(y)

# %%
# (a)
y_0 = 0

def exact_sol(t):
    return 2*arctan(exp(t)*tan(y_0/2)) + 2*pi*int((y_0 + pi)/(2*pi))

# %%
plt.figure()

true_value = exact_sol(t_list)
plt.plot(t_list, true_value, label='Exact solution')

for i, h in enumerate([h_list[0], h_list[-1]]):
    t, w = Euler_method(f, a, b, h, y_0)
    plt.plot(t, w, label='k: %d' % (5*i))
    
plt.legend()
plt.show()

# %%
f_4 = exact_sol(4)
error_list = np.zeros(6)
for i, h in enumerate(h_list):
    t, w = Euler_method(f, a, b, h, y_0)
    error_list[i] = abs(w[-1] - f_4)
# Since the initial value is 0, the solution of the ODE is 0.
# Therefore the Euler's method can precisely calculate the result.
    
plt.plot(h_list, error_list)
plt.xlabel('h')
plt.ylabel("Error")
plt.xscale("log")
plt.yscale("log")
plt.show()
# Out:
# C:\Users\snuist\Anaconda3\lib\site-packages\matplotlib\ticker.py:2206: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   "Data has no positive values, and therefore cannot be "

# %%
# (b)
y_0 = 100

def exact_sol(t):
    return 2*arctan(exp(t)*tan(y_0/2)) + 2*pi*int((y_0 + pi)/(2*pi))

# %%
plt.figure()

true_value = exact_sol(t_list)
plt.plot(t_list, true_value, label='Exact solution')

for i, h in enumerate([h_list[0], h_list[-1]]):
    t, w = Euler_method(f, a, b, h, y_0)
    plt.plot(t, w, label='k: %d' % (5*i))
    
plt.legend()
plt.show()

# %%
f_4 = exact_sol(4)
error_list = np.zeros(6)
for i, h in enumerate(h_list):
    t, w = Euler_method(f, a, b, h, y_0)
    error_list[i] = abs(w[-1] - f_4)

plt.plot(h_list, error_list)
plt.xlabel('h')
plt.ylabel("Error")
plt.xscale("log")
plt.yscale("log")
plt.show()

# %% [markdown]
# ### Q. 10

# %%
h_list = [0.1 * 2**(-k) for k in range(6)]
t_list = np.arange(a, b+h_list[-1], h_list[-1])

def f(t, y):
    return sinh(y)

# %%
# (a)
a, b = 0, 2
y_0 = 1/4

def exact_sol(t):
    return 2*arctanh(exp(t)*tanh(y_0/2))

# %%
plt.figure()

true_value = exact_sol(t_list)
plt.plot(t_list, true_value, label='Exact solution')

for i, h in enumerate([h_list[0], h_list[-1]]):
    t, w = Euler_method(f, a, b, h, y_0)
    plt.plot(t, w, label='k: %d' % (5*i))
    
plt.legend()
plt.show()
# Out:
# C:\Users\snuist\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: RuntimeWarning: invalid value encountered in arctanh

# %%
f_2 = exact_sol(2)
error_list = np.zeros(6)
for i, h in enumerate(h_list):
    t, w = Euler_method(f, a, b, h, y_0)
    error_list[i] = abs(w[-1] - f_2)

plt.plot(h_list, error_list)
plt.xlabel('h')
plt.ylabel("Error")
plt.xscale("log")
plt.yscale("log")
plt.show()

# %%
# (b)
a, b = 0, 1/4
y_0 = 2

def exact_sol(t):
    return 2*arctanh(exp(t)*tanh(y_0/2))

# %%
plt.figure()

true_value = exact_sol(t_list)
plt.plot(t_list, true_value, label='Exact solution')

for i, h in enumerate([h_list[0], h_list[-1]]):
    t, w = Euler_method(f, a, b, h, y_0)
    plt.plot(t, w, label='k: %d' % (5*i))
    
plt.legend()
plt.show()
# Out:
# C:\Users\snuist\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: RuntimeWarning: invalid value encountered in arctanh

# %%
f_025 = exact_sol(1/4)
error_list = np.zeros(6)
for i, h in enumerate(h_list):
    t, w = Euler_method(f, a, b, h, y_0)
    error_list[i] = abs(w[-1] - f_025)

plt.plot(h_list, error_list)
plt.xlabel('h')
plt.ylabel("Error")
plt.xscale("log")
plt.yscale("log")
plt.show()

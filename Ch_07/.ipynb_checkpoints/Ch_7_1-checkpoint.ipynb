# %% [markdown]
# # Chapter 7<br>Boundary Value Problems

# %% [markdown]
# ## 7.1 Shooting Method

# %%
import numpy as np
from numpy import e, pi, log, exp, sqrt, sin, arcsin, sinh, cos, tan, arctan, tanh, arctanh
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
def RKF45(f, a, b, tol, y_0):
    h = b - a
    
    t_i = a
    w_i = np.array(y_0)
    t = [t_i]
    w = [w_i]
    doubled = False
        
    while t_i < b:
        s_1 = f(t_i, w_i)
        s_2 = f(t_i + h/4, w_i + h*s_1/4)
        s_3 = f(t_i + h*3/8, w_i + h*s_1*3/32 + h*s_2*9/32)
        s_4 = f(t_i + h*12/13, w_i + h*s_1*1932/2197 - h*s_2*7200/2197 + 
                h*s_3*7296/2197)
        s_5 = f(t_i + h, w_i + h*s_1*439/216 - h*s_2*8 + h*s_3*3680/513 -
               h*s_4*845/4104)
        s_6 = f(t_i + h/2, w_i - h*s_1*8/27 + h*s_2*2 - h*s_3*3544/2565 + 
               h*s_4*1859/4104 - h*s_5*11/40)

        w_ii = w_i + h*(s_1*25/216 + s_3*1408/2565 + s_4*2197/4104 - s_5/5)
        z_ii = w_i + h*(s_1*16/135 + s_3*6656/12825 + s_4*28561/56430 -
                        s_5*9/50 + s_6*2/55)
        e_ii = abs(w_ii - z_ii)
        
        rel_error = abs(np.max(e_ii / w_ii))
        if doubled:
            doubled = False
            pass
        elif rel_error > tol:
            h *= 0.8 * pow(tol / rel_error, 1/5)
            continue
        elif t_i + h > b:
            h = b - t_i
            continue

        t_i += h
        w_i = z_ii
        t.append(t_i)
        w.append(w_i)
        
        if (rel_error < tol/10) & (t_i + h < b):
            h *= 2
            doubled = True
    
    return t, np.array(w).T

# %%
def find_interval(f, a, b, tol, y_boundary, mean=0, var=1, count=1000, find_y2=False):
    y_a, y_b = y_boundary

    for num in range(count):
        s_interval = var*np.random.randn(2) + mean
        s_interval.sort()
        test = 1

        for s in s_interval:
            y_0 = (y_a, s)
            t, y = RKF45(f, a, b, tol, y_0)
            test *= (y[int(find_y2)][-1] - y_b)

        if test < 0:
            return s_interval.tolist()
    
    return False

# %%
def Shooting(f, a, b, tol, y_boundary, s_interval, find_y2=False):
    s0, s1 = s_interval
    y_a, y_b = y_boundary
    F_s = [0] * 2

    for i in range(2):
        s = s_interval[i]
        y_0 = (y_a, s)
        t, y = RKF45(f, a, b, tol, y_0)
        F_s[i] = y[int(find_y2)][-1] - y_b
    
    while True:
        c = (s0 + s1) / 2
        if s1 - s0 < tol:
            break;

        y_0 = (y_a, c)
        t, y = RKF45(f, a, b, tol, y_0)
        temp = y[int(find_y2)][-1] - y_b

        if temp * F_s[0] > 0:
            s0 = c
            F_s[0] = temp
            continue
        elif temp * F_s[1] > 0:
            s1 = c
            F_s[1] = temp
            continue
        else:
            break
    y_0 = (y_a, c)
    
    return RKF45(f, a, b, tol, y_0)

# %% [markdown]
# ### Q. 1

# %%
tol = 1e-8

# %%
# (a)
a, b = 0, 1
y_boundary = 0, e/3

def f(t, y):
    y1, y2 = y
    equation = [y2, y1 + exp(t)*2/e]
    return np.array(equation)

# %%
s_interval = find_interval(f, a, b, tol, y_boundary)
t, y = Shooting(f, a, b, tol, y_boundary, s_interval)

print("Interval: [%.4f, %.4f]" % (s_interval[0], s_interval[1]))

plt.plot(t, y[0], label="Solution")
plt.legend()
plt.show()
# Out:
# Interval: [-1.3215, 0.7139]

# %%
# (b)
a, b = 0, 1
y_boundary = 1, e

def f(t, y):
    y1, y2 = y
    equation = [y2, (2 + 4*t**2)*y1]
    return np.array(equation)

# %%
s_interval = find_interval(f, a, b, tol, y_boundary)
t, y = Shooting(f, a, b, tol, y_boundary, s_interval)

print("Interval: [%.4f, %.4f]" % (s_interval[0], s_interval[1]))

plt.plot(t, y[0], label="Solution")
plt.legend()
plt.show()
# Out:
# Interval: [-1.0401, 0.5555]

# %% [markdown]
# ### Q. 2

# %%
tol = 1e-8

# %%
# (a)
a, b = 0, 3/2
y_boundary = -1, 3

def f(t, y):
    y1, y2 = y
    equation = [y2, -(pi**2 * y1) / 9]
    return np.array(equation)

# %%
s_interval = find_interval(f, a, b, tol, y_boundary)
t, y = Shooting(f, a, b, tol, y_boundary, s_interval)

print("Interval: [%.4f, %.4f]" % (s_interval[0], s_interval[1]))

plt.plot(t, y[0], label="Solution")
plt.legend()
plt.show()
# Out:
# Interval: [-0.5601, 3.3060]

# %%
# (b)
a, b = 0, 1
y_boundary = exp(3), 1

def f(t, y):
    y1, y2 = y
    equation = [y2, 3*y1 - 2*y2]
    return np.array(equation)

# %%
s_interval = find_interval(f, a, b, tol, y_boundary, mean=-40, var=10)
t, y = Shooting(f, a, b, tol, y_boundary, s_interval)

print("Interval: [%.4f, %.4f]" % (s_interval[0], s_interval[1]))

plt.plot(t, y[0], label="Solution")
plt.legend()
plt.show()
# Out:
# Interval: [-62.9314, -45.3758]

# %% [markdown]
# ### Q. 3

# %%
tol = 1e-8

# %%
# (a)
a, b = 1, 2
y_boundary = 1/3, 1/12

def f(t, y):
    y1, y2 = y
    equation = [y2, 18*(y1**2)]
    return np.array(equation)

# %%
s_interval = find_interval(f, a, b, tol, y_boundary, mean=-2)
t, y = Shooting(f, a, b, tol, y_boundary, s_interval)

print("Interval: [%.4f, %.4f]" % (s_interval[0], s_interval[1]))

plt.plot(t, y[0], label="Solution")
plt.legend()
plt.show()
# Out:
# Interval: [-1.5368, 0.4824]

# %%
# (b)
a, b = 0, 1
y_boundary = 0, log(2)

def f(t, y):
    y1, y2 = y
    equation = [y2, 2*exp(-2*y1)*(1 - t**2)]
    return np.array(equation)

# %%
s_interval = find_interval(f, a, b, tol, y_boundary)
t, y = Shooting(f, a, b, tol, y_boundary, s_interval)

print("Interval: [%.4f, %.4f]" % (s_interval[0], s_interval[1]))

plt.plot(t, y[0], label="Solution")
plt.legend()
plt.show()
# Out:
# Interval: [-0.7802, 0.5359]

# %% [markdown]
# ### Q. 4

# %%
tol = 1e-8

# %%
# (a)
a, b = 0, 1
y_boundary = 1, 3

def f(t, y):
    y1, y2 = y
    equation = [y2, exp(y1)]
    return np.array(equation)

# %%
s_interval = find_interval(f, a, b, tol, y_boundary)
t, y = Shooting(f, a, b, tol, y_boundary, s_interval)

print("Interval: [%.4f, %.4f]" % (s_interval[0], s_interval[1]))

plt.plot(t, y[0], label="Solution")
plt.legend()
plt.show()
# Out:
# Interval: [-1.6250, 0.2833]

# %%
# (b)
a, b = 0, 1
y_boundary = 1, -1

def f(t, y):
    y1, y2 = y
    equation = [y2, sin(y2)]
    return np.array(equation)

# %%
s_interval = find_interval(f, a, b, tol, y_boundary)
t, y = Shooting(f, a, b, tol, y_boundary, s_interval)

print("Interval: [%.4f, %.4f]" % (s_interval[0], s_interval[1]))

plt.plot(t, y[0], label="Solution")
plt.legend()
plt.show()
# Out:
# Interval: [-1.6056, -1.1571]

# %% [markdown]
# ### Q. 5

# %%
tol = 1e-8

# %%
# (a)
a, b = 0, 1
y_values = 0, 2

def f(t, y):
    y1, y2 = y
    equation = [1/y2, t + tan(y1)]
    return np.array(equation)

# %%
s_interval = find_interval(f, a, b, tol, y_values, mean=1, find_y2=True)
t, y = Shooting(f, a, b, tol, y_values, s_interval, find_y2=True)

print("Interval: [%.4f, %.4f]" % (s_interval[0], s_interval[1]))

plt.plot(t, y[0], label="Solution $y_1$")
plt.plot(t, y[1], label="Solution $y_2$")
plt.legend()
plt.show()
# Out:
# Interval: [-0.8022, 2.0377]

# %%
# (b)
a, b = 0, 1
y_values = 1, -2/3

def f(t, y):
    y1, y2 = y
    equation = [y1 - 3*y1*y2, -6*(t*y2 + log(y1))]
    return np.array(equation)

# %%
s_interval = find_interval(f, a, b, tol, y_values, mean=1, find_y2=True)
t, y = Shooting(f, a, b, tol, y_values, s_interval, find_y2=True)

print("Interval: [%.4f, %.4f]" % (s_interval[0], s_interval[1]))

plt.plot(t, y[0], label="Solution $y_1$")
plt.plot(t, y[1], label="Solution $y_2$")
plt.legend()
plt.show()
# Out:
# /home/wooyoung/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: RuntimeWarning: invalid value encountered in log
#   import sys
# Interval: [-0.1440, 0.4502]
